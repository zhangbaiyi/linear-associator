# %%
import pandas as pd
import numpy as np
import dataframe_image as dfi


data_path = "../data/"

# %%
all_assets_df = pd.read_csv(data_path+"ALL_Assets.csv",encoding = "utf-8-sig")
all_assets_df
# Out:
#                 id  rank symbol      name        supply    maxSupply  \
# 0          bitcoin     1    BTC   Bitcoin  1.965837e+07   21000000.0
# 1         ethereum     2    ETH  Ethereum  1.200774e+08          NaN
# 2           tether     3   USDT    Tether  1.036182e+11          NaN
# 3     binance-coin     4    BNB       BNB  1.668011e+08  166801148.0
# 4           solana     5    SOL    Solana  4.438849e+08          NaN
# ...            ...   ...    ...       ...           ...          ...
# 1995         seele  1996  SEELE   Seele-N  0.000000e+00          NaN
# 1996          seer  1997   SEER      SEER           NaN          NaN
# 1997      segwit2x  1998    B2X  SegWit2x           NaN   21000000.0
# 1998      selfsell  1999    SSC  SelfSell  3.900000e+08          NaN
# 1999      senderon  2000   SDRN  Senderon  4.562590e+07          NaN
#
#       marketCapUsd  volumeUsd24Hr      priceUsd  changePercent24Hr  \
# 0     1.303884e+12   1.212996e+10  66327.148890          -1.939361
# 1     4.231424e+11   7.009960e+09   3523.912627          -0.801426
# 2     1.037045e+11   2.763992e+10      1.000833          -0.069075
# 3     9.732062e+10   8.343984e+08    583.452964           5.366770
# 4     7.984135e+10   1.762365e+09    179.869480          -5.553039
# ...            ...            ...           ...                ...
# 1995           NaN            NaN      0.000023                NaN
# 1996           NaN            NaN      0.000107                NaN
# 1997           NaN            NaN      4.747940                NaN
# 1998           NaN            NaN      9.718463                NaN
# 1999           NaN            NaN      0.000436                NaN
#
#           vwap24Hr                                           explorer
# 0     66267.346653                           https://blockchain.info/
# 1      3516.792519                              https://etherscan.io/
# 2         1.001213             https://www.omniexplorer.info/asset/31
# 3       563.366159  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4       182.831453                       https://explorer.solana.com/
# ...            ...                                                ...
# 1995           NaN  https://etherscan.io/token/0xb1eef147028e9f480...
# 1996           NaN  https://etherscan.io/token/0x0f1ed66c251bcb52e...
# 1997           NaN                     http://explorer.b2x-segwit.io/
# 1998           NaN                      https://browser.selfsell.com/
# 1999           NaN  https://etherscan.io/token/0x73b534fb6f07381a2...
#
# [2000 rows x 12 columns]

# %%
all_assets_price_df = pd.read_csv(data_path+"ALL_Assets_price_raw.csv",encoding = "utf-8-sig", index_col=0)
all_assets_price_df
# Out:
#                                 bitcoin     ethereum    tether  binance-coin  \
# date
# 2014-01-03 00:00:00+00:00    807.038818          NaN       NaN           NaN
# 2014-01-05 00:00:00+00:00    883.669371          NaN       NaN           NaN
# 2014-01-07 00:00:00+00:00    899.791962          NaN       NaN           NaN
# 2014-01-08 00:00:00+00:00    829.105342          NaN       NaN           NaN
# 2014-01-09 00:00:00+00:00    837.525111          NaN       NaN           NaN
# ...                                 ...          ...       ...           ...
# 2024-03-17 00:00:00+00:00  67075.366843  3582.271598  1.000208    576.672579
# 2024-03-18 00:00:00+00:00  67803.769903  3567.616752  1.000739    561.284087
# 2024-03-19 00:00:00+00:00  64392.559734  3322.053274  1.000274    524.195936
# 2024-03-20 00:00:00+00:00  63887.775990  3289.108261  1.000647    527.806801
# 2024-03-21 00:00:00+00:00  66707.021708  3514.274264  1.000995    555.909109
#
#                                solana  usd-coin       xrp  dogecoin   cardano  \
# date
# 2014-01-03 00:00:00+00:00         NaN       NaN       NaN       NaN       NaN
# 2014-01-05 00:00:00+00:00         NaN       NaN       NaN       NaN       NaN
# 2014-01-07 00:00:00+00:00         NaN       NaN       NaN       NaN       NaN
# 2014-01-08 00:00:00+00:00         NaN       NaN       NaN       NaN       NaN
# 2014-01-09 00:00:00+00:00         NaN       NaN       NaN       NaN       NaN
# ...                               ...       ...       ...       ...       ...
# 2024-03-17 00:00:00+00:00  190.775299  1.001094  0.614723  0.148890  0.672038
# 2024-03-18 00:00:00+00:00  202.260403  1.001265  0.614191  0.146979  0.668761
# 2024-03-19 00:00:00+00:00  181.105944  1.000652  0.601550  0.132726  0.618317
# 2024-03-20 00:00:00+00:00  175.271056  1.001020  0.594147  0.134910  0.607420
# 2024-03-21 00:00:00+00:00  186.756380  1.001061  0.622298  0.152505  0.634803
#
#                            avalanche  ...  sapphire  savedroid  scorecoin  \
# date                                  ...
# 2014-01-03 00:00:00+00:00        NaN  ...       NaN        NaN        NaN
# 2014-01-05 00:00:00+00:00        NaN  ...       NaN        NaN        NaN
# 2014-01-07 00:00:00+00:00        NaN  ...       NaN        NaN        NaN
# 2014-01-08 00:00:00+00:00        NaN  ...       NaN        NaN        NaN
# 2014-01-09 00:00:00+00:00        NaN  ...       NaN        NaN        NaN
# ...                              ...  ...       ...        ...        ...
# 2024-03-17 00:00:00+00:00  54.794991  ...       NaN        NaN        NaN
# 2024-03-18 00:00:00+00:00  61.461631  ...       NaN        NaN        NaN
# 2024-03-19 00:00:00+00:00  57.931063  ...       NaN        NaN        NaN
# 2024-03-20 00:00:00+00:00  53.567902  ...       NaN        NaN        NaN
# 2024-03-21 00:00:00+00:00  54.991942  ...       NaN        NaN        NaN
#
#                            seal-network  securecoin  seele  seer  segwit2x  \
# date
# 2014-01-03 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2014-01-05 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2014-01-07 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2014-01-08 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2014-01-09 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# ...                                 ...         ...    ...   ...       ...
# 2024-03-17 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2024-03-18 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2024-03-19 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2024-03-20 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
# 2024-03-21 00:00:00+00:00           NaN         NaN    NaN   NaN       NaN
#
#                            selfsell  senderon
# date
# 2014-01-03 00:00:00+00:00       NaN       NaN
# 2014-01-05 00:00:00+00:00       NaN       NaN
# 2014-01-07 00:00:00+00:00       NaN       NaN
# 2014-01-08 00:00:00+00:00       NaN       NaN
# 2014-01-09 00:00:00+00:00       NaN       NaN
# ...                             ...       ...
# 2024-03-17 00:00:00+00:00       NaN       NaN
# 2024-03-18 00:00:00+00:00       NaN       NaN
# 2024-03-19 00:00:00+00:00       NaN       NaN
# 2024-03-20 00:00:00+00:00       NaN       NaN
# 2024-03-21 00:00:00+00:00       NaN       NaN
#
# [3663 rows x 1988 columns]
